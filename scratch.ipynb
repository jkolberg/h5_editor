# %%
import pandas as pd

# %%
h5_path = "L:/base_year_2023_inputs/urbansim2_inputs/psrc_base_year_2023_alloc_py3.h5"
with pd.HDFStore(h5_path, "r") as f:
    print(list(f.keys()))
# Out:
# ['/annual_employment_control_totals', '/annual_household_control_totals', '/annual_household_relocation_rates', '/annual_job_relocation_rates', '/building_sqft_per_job', '/building_types', '/buildings', '/cities', '/control_hct_crosswalk', '/control_hcts', '/controls', '/counties', '/development_constraints', '/development_template_components', '/development_templates', '/employment_adhoc_sector_group_definitions', '/employment_adhoc_sector_groups', '/employment_sectors', '/fazes', '/gridcells', '/households', '/households_events', '/households_zone_control_hct_events', '/jobs', '/land_use_types', '/mpds', '/parcels', '/persons', '/schools', '/subregs', '/target_vacancies', '/targets', '/travel_data', '/zone_control_hcts', '/zones', '/zoning_heights']
